# %%
import pandas as pd 
pd.set_option("display.max_columns", None)
import numpy as np
import piplite
await piplite.install(['skillsnetwork'])
import skillsnetwork

# %%
df=pd.read_csv('2015.csv')

# %%
df.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %%
df=df.rename(columns={"Country":"Ulke","Region": "Bolge","Happiness Score":"Mutluluk Skor","Health (Life Expectancy)":"Yasam Kalitesi","Freedom":"Ozgurluk" })

# %%
df.head(5)
# Out:
#           ülke           Bolge  Happiness Rank  Mutluluk Skor  Standard Error  \
# 0  Switzerland  Western Europe               1          7.587         0.03411
# 1      Iceland  Western Europe               2          7.561         0.04884
# 2      Denmark  Western Europe               3          7.527         0.03328
# 3       Norway  Western Europe               4          7.522         0.03880
# 4       Canada   North America               5          7.427         0.03553
#
#    Economy (GDP per Capita)   Family  Yasam Kalitesi  Ozgurluk  \
# 0                   1.39651  1.34951         0.94143   0.66557
# 1                   1.30232  1.40223         0.94784   0.62877
# 2                   1.32548  1.36058         0.87464   0.64938
# 3                   1.45900  1.33095         0.88521   0.66973
# 4                   1.32629  1.32261         0.90563   0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# ...

# %%
df.columns=df.columns.str.replace(" ","_")

# %%
df.head(5)
# Out:
#           ülke           Bolge  Happiness_Rank  Mutluluk_Skor  Standard_Error  \
# 0  Switzerland  Western Europe               1          7.587         0.03411
# 1      Iceland  Western Europe               2          7.561         0.04884
# 2      Denmark  Western Europe               3          7.527         0.03328
# 3       Norway  Western Europe               4          7.522         0.03880
# 4       Canada   North America               5          7.427         0.03553
#
#    Economy_(GDP_per_Capita)   Family  Yasam_Kalitesi  Ozgurluk  \
# 0                   1.39651  1.34951         0.94143   0.66557
# 1                   1.30232  1.40223         0.94784   0.62877
# 2                   1.32548  1.36058         0.87464   0.64938
# 3                   1.45900  1.33095         0.88521   0.66973
# 4                   1.32629  1.32261         0.90563   0.63297
#
#    Trust_(Government_Corruption)  Generosity  Dystopia_Residual
# ...

# %%
df.shape
# Out:
# (158, 12)

# %%
tekrarlanan_veri=df[df.duplicated()]
print("Tekrarlanan veri sayisi ", tekrarlanan_veri.shape)
# Out:
# Tekrarlanan veri sayisi  (0, 12)

# %%
df.count()
# Out:
# ülke                             158
# Bolge                            158
# Happiness_Rank                   158
# Mutluluk_Skor                    158
# Standard_Error                   158
# Economy_(GDP_per_Capita)         158
# Family                           158
# Yasam_Kalitesi                   158
# Ozgurluk                         158
# Trust_(Government_Corruption)    158
# Generosity                       158
# Dystopia_Residual                158
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# ülke                             0
# Bolge                            0
# Happiness_Rank                   0
# Mutluluk_Skor                    0
# Standard_Error                   0
# Economy_(GDP_per_Capita)         0
# Family                           0
# Yasam_Kalitesi                   0
# Ozgurluk                         0
# Trust_(Government_Corruption)    0
# Generosity                       0
# Dystopia_Residual                0
# dtype: int64

# %%
import piplite
await piplite.install('seaborn')

# %%
import seaborn as sns

# %%
sns.boxplot(x=df['Mutluluk_Skor'])
# Out:
# <AxesSubplot:xlabel='Mutluluk_Skor'>

# %%
df.Mutluluk_Skor.value_counts().nlargest(30).plot(kind='bar',figsize=(8,6))
# Out:
# <AxesSubplot:>

# %%
sns.barplot(y = df["ülke"][:10], x = df["Mutluluk_Skor"][:10])
# Out:
# <AxesSubplot:xlabel='Mutluluk_Skor', ylabel='ülke'>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df['ülke'], df['Mutluluk_Skor'])
ax.set_xlabel('ülke')
ax.set_ylabel('Mutluluk_Skor')
plt.show()

# %%
sns.barplot(y = df["ülke"][-10:], x = df["Mutluluk_Skor"][-10:])
# Out:
# <AxesSubplot:xlabel='Mutluluk_Skor', ylabel='ülke'>

# %%
turk_sira=df[df["ülke"]=="Turkey"]
turk_sira
# Out:
#       ülke                            Bolge  Happiness_Rank  Mutluluk_Skor  \
# 75  Turkey  Middle East and Northern Africa              76          5.332
#
#     Standard_Error  Economy_(GDP_per_Capita)   Family  Yasam_Kalitesi  \
# 75         0.03864                   1.06098  0.94632         0.73172
#
#     Ozgurluk  Trust_(Government_Corruption)  Generosity  Dystopia_Residual
# 75   0.22815                        0.15746     0.12253            2.08528

# %%
f, axs=plt.subplots(3,2, figsize=(10,5),constrained_layout =True)

# %%
f, axs = plt.subplots(2,2, figsize = (14,14), constrained_layout = True)
sort_eco = df.sort_values(by = ['Economy_(GDP_per_Capita)'], ascending = False)
sort_eco = sort_eco.head(10)
sort_Yasam_Kalitesi = df.sort_values(by = ['Yasam_Kalitesi'], ascending =False)
sort_Yasam_Kalitesi = sort_Yasam_Kalitesi.head(10)
sort_Family = df.sort_values(by = ['Family'], ascending =False)
sort_Family=sort_Family.head(10)
sort_Ozgurluk = df.sort_values(by = ['Ozgurluk'], ascending =False)
sort_Ozgurluk=sort_Ozgurluk.head(10)
ax=sns.barplot(x="ülke", y="Economy_(GDP_per_Capita)", data=sort_eco, ax = axs[0, 0])
ax.tick_params(axis = 'x', rotation = 45)
ax=sns.barplot(x="ülke", y="Yasam_Kalitesi", data=sort_eco, ax = axs[0, 1])
ax.tick_params(axis = 'x', rotation = 45)
ax=sns.barplot(x="ülke", y="Family", data=sort_eco, ax = axs[1, 1])
ax.tick_params(axis = 'x', rotation = 45)
ax=sns.barplot(x="ülke", y="Ozgurluk", data=sort_eco, ax = axs[1, 0])
ax.tick_params(axis = 'x', rotation = 45)

# %%
df2016=pd.read_csv('2016.csv')

# %%
df2017=pd.read_csv('2017.csv')
df2018=pd.read_csv('2018.csv')
df2019=pd.read_csv('2019.csv')

# %%
df2016.head(1)
# Out:
#    Country          Region  Happiness Rank  Happiness Score  \
# 0  Denmark  Western Europe               1            7.526
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                       7.46                      7.592
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.44453     0.36171            2.73939

# %%
df2016.columns=df2016.columns.str.replace(' ','_')

# %%
df2017.head(1)
# Out:
#   Country  Happiness_Rank  Happiness_Score  Whisker_high  Whisker_low  \
# 0  Norway               1            7.537      7.594445     7.479556
#
#    Economy__GDP_per_Capita_    Family  Health__Life_Expectancy_   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
#
#    Generosity  Trust__Government_Corruption_  Dystopia_Residual
# 0    0.362012                       0.315964           2.277027

# %%
df2017.columns=df2017.columns.str.replace('__','_')

# %%
df2017=df2017.rename(columns={"Economy_GDP_per_Capita_":"Economy","Health_Life_Expectancy_":"Life_Expectancy",
                      "Trust_Government_Corruption_":"Government_Corruption","Happiness_Rank":"Rank"
                      })

# %%
df2016=df2016.rename(columns={"Economy_(GDP_per_Capita)":"Economy","Health_(Life_Expectancy)":"Life_Expectancy",
                      "Trust_(Government_Corruption)":"Government_Corruption","Happiness_Rank":"Rank"
                      })

# %%
df2018.head(1)
# Out:
#    Overallrank Countryorregion  Score  GDPpercapita  Socialsupport  \
# 0            1         Finland  7.632         1.305          1.592
#
#    Healthylifeexpectancy  Freedomtomakelifechoices  Generosity  \
# 0                  0.874                     0.681       0.202
#
#    Perceptionsofcorruption
# 0                    0.393

# %%
df2018.columns=df2018.columns.str.replace(' ','')

# %%
df2018.head(1)
# Out:
#    Overallrank Countryorregion  Score  GDPpercapita  Socialsupport  \
# 0            1         Finland  7.632         1.305          1.592
#
#    Healthylifeexpectancy  Freedomtomakelifechoices  Generosity  \
# 0                  0.874                     0.681       0.202
#
#    Perceptionsofcorruption
# 0                    0.393

# %%
df2018=df2018.rename(columns={"GDPpercapita":"Economy","Healthylifeexpectancy":"Life_Expectancy",
                      "Score":"Happiness_Score","Overallrank":"Rank"
                      })

# %%
df2019.head(1)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769            1.34           1.587
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
#
#    Perceptions of corruption
# 0                      0.393

# %%
df2019.columns=df2019.columns.str.replace(' ','')

# %%
df2019.head(1)
# Out:
#    Overallrank Countryorregion  Score  GDPpercapita  Socialsupport  \
# 0            1         Finland  7.769          1.34          1.587
#
#    Healthylifeexpectancy  Freedomtomakelifechoices  Generosity  \
# 0                  0.986                     0.596       0.153
#
#    Perceptionsofcorruption
# 0                    0.393

# %%
df2019=df2019.rename(columns={"GDPpercapita":"Economy","Healthylifeexpectancy":"Life_Expectancy",
                      "Score":"Happiness_Score","Overallrank":"Rank"
                      })

# %%
f, axs = plt.subplots(2,2, figsize = (10,10), constrained_layout = True)
sort_2016 = df2016.sort_values(by = ['Life_Expectancy'], ascending = False)
sort_2016 = sort_2016.head(10)
ax=sns.barplot(x="Happiness_Score", y="Life_Expectancy", data=sort_2016, ax = axs[0, 0])
ax.tick_params(axis = 'x', rotation = 45)
sort_2017 = df2017.sort_values(by = ['Life_Expectancy'], ascending = False)
sort_2017 = sort_2017.head(10)
ax=sns.barplot(x="Happiness_Score", y="Life_Expectancy", data=sort_2017, ax = axs[0, 1])
ax.tick_params(axis = 'x', rotation = 45)
sort_2018 = df2018.sort_values(by = ['Life_Expectancy'], ascending = False)
sort_2018 = sort_2018.head(10)
ax=sns.barplot(x="Happiness_Score", y="Life_Expectancy", data=sort_2018, ax = axs[1, 0])
ax.tick_params(axis = 'x', rotation = 45)
sort_2019 = df2019.sort_values(by = ['Life_Expectancy'], ascending = False)
sort_2019 = sort_2019.head(10)
ax=sns.barplot(x="Happiness_Score", y="Life_Expectancy", data=sort_2019, ax = axs[1, 1])
ax.tick_params(axis = 'x', rotation = 45)

# %%
df2016.head(1)
# Out:
#    Country          Region  Rank  Happiness_Score  Lower_Confidence_Interval  \
# 0  Denmark  Western Europe     1            7.526                       7.46
#
#    Upper_Confidence_Interval  Economy   Family  Life_Expectancy  Freedom  \
# 0                      7.592  1.44178  1.16374          0.79504  0.57941
#
#    Government_Corruption  Generosity  Dystopia_Residual
# 0                0.44453     0.36171            2.73939

# %%
df2017.head(1)
# Out:
#   Country  Rank  Happiness_Score  Whisker_high  Whisker_low   Economy  \
# 0  Norway     1            7.537      7.594445     7.479556  1.616463
#
#      Family  Life_Expectancy   Freedom  Generosity  Government_Corruption  \
# 0  1.533524         0.796667  0.635423    0.362012               0.315964
#
#    Dystopia_Residual
# 0           2.277027

# %%
df2018.head(1)
# Out:
#    Country          Region  Rank  Happiness_Score  Lower_Confidence_Interval  \
# 0  Denmark  Western Europe     1            7.526                       7.46
#
#    Upper_Confidence_Interval  Economy   Family  Life_Expectancy  Freedom  \
# 0                      7.592  1.44178  1.16374          0.79504  0.57941
#
#    Government_Corruption  Generosity  Dystopia_Residual
# 0                0.44453     0.36171            2.73939

# %%
df2019.head(1)
# Out:
#    Rank Countryorregion  Happiness_Score  Economy  Socialsupport  \
# 0     1         Finland            7.769     1.34          1.587
#
#    Life_Expectancy  Freedomtomakelifechoices  Generosity  \
# 0            0.986                     0.596       0.153
#
#    Perceptionsofcorruption
# 0                    0.393

# %%
df2019=df2019.rename(columns={"Countryorregion":"Country"})
df2019.head(1)
# Out:
#    Rank  Country  Happiness_Score  Economy  Socialsupport  Life_Expectancy  \
# 0     1  Finland            7.769     1.34          1.587            0.986
#
#    Freedomtomakelifechoices  Generosity  Perceptionsofcorruption
# 0                     0.596       0.153                    0.393

# %%
f ,axs= plt.subplots(2,2,figsize=(8,8),constrained_layout=True)
sortCountry16=df2016.sort_values(by=['Happiness_Score'],ascending =False)
sortCountry16=sortCountry16.head(5)
sortCountry17=df2017.sort_values(by=['Happiness_Score'],ascending =False)
sortCountry17=sortCountry17.head(5)
sortCountry18=df2018.sort_values(by=['Happiness_Score'],ascending =False)
sortCountry18=sortCountry18.head(5)
sortCountry19=df2019.sort_values(by=['Happiness_Score'],ascending =False)
sortCountry19=sortCountry19.head(5)
ax=sns.barplot(x="Country", y="Happiness_Score", data=sortCountry16, ax = axs[0, 0])
ax.tick_params(axis = 'x', rotation = 45)
ax=sns.barplot(x="Country", y="Happiness_Score", data=sortCountry17, ax = axs[0, 1])
ax.tick_params(axis = 'x', rotation = 45)
ax=sns.barplot(x="Country", y="Happiness_Score", data=sortCountry18, ax = axs[1, 0])
ax.tick_params(axis = 'x', rotation = 45)
ax=sns.barplot(x="Country", y="Happiness_Score", data=sortCountry19, ax = axs[1, 1])
ax.tick_params(axis = 'x', rotation = 45)
axs[0, 0].title.set_text('2016 YILI EN MUTLU 5 ULKE')
axs[0, 1].title.set_text('2017 YILI EN MUTLU 5 ULKE')
axs[1, 0].title.set_text('2018 YILI EN MUTLU 5 ULKE')
axs[1, 1].title.set_text('2019 YILI EN MUTLU 5 ULKE')

# %% [markdown]
# ## Aşağıda olan en mutsuz ülkeler 2016 dan 2019 a kadar

# %%
f ,axs= plt.subplots(2,2,figsize=(8,8),constrained_layout=True)
Country16=df2016.sort_values(by=['Happiness_Score'],ascending =False)
Country16=Country16.tail(5)
Country17=df2017.sort_values(by=['Happiness_Score'],ascending =False)
Country17=Country17.tail(5)
Country18=df2018.sort_values(by=['Happiness_Score'],ascending =False)
Country18=Country18.tail(5)
Country19=df2019.sort_values(by=['Happiness_Score'],ascending =False)
Country19=Country19.tail(5)
ax=sns.barplot(x="Life_Expectancy", y="Happiness_Score", data=Country16, ax = axs[0, 0])
ax.tick_params(axis = 'x', rotation = 45)
ax=sns.barplot(x="Life_Expectancy", y="Happiness_Score", data=Country17, ax = axs[0, 1])
ax.tick_params(axis = 'x', rotation = 45)
ax=sns.barplot(x="Life_Expectancy", y="Happiness_Score", data=Country18, ax = axs[1, 0])
ax.tick_params(axis = 'x', rotation = 45)
ax=sns.barplot(x="Life_Expectancy", y="Happiness_Score", data=Country19, ax = axs[1, 1])
ax.tick_params(axis = 'x', rotation = 45)
axs[0,0].title.set_text('2016 yılı pahalılık mutluluk ilişkisi')
axs[0,1].title.set_text('2017 yılı pahalılık mutluluk ilişkisi')
axs[1,0].title.set_text('2018 yılı pahalılık mutluluk ilişkisi')
axs[1,1].title.set_text('2019 yılı pahalılık mutluluk ilişkisi')

# %% [markdown]
# ## En mutsuz ülkeler sırasıyla gidiyor

# %%
plt.figure(figsize=(10,5))
sicaklik2019=df2019.corr()
sns.heatmap(sicaklik2019,cmap="BrBG",annot=True)
sicaklik2019
# Out:
# <ipython-input-151-2e63e4743b37>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sicaklik2019=df2019.corr()
#                               Rank  Happiness_Score   Economy  Socialsupport  \
# Rank                      1.000000        -0.989096 -0.801947      -0.767465
# Happiness_Score          -0.989096         1.000000  0.793883       0.777058
# Economy                  -0.801947         0.793883  1.000000       0.754906
# Socialsupport            -0.767465         0.777058  0.754906       1.000000
# Life_Expectancy          -0.787411         0.779883  0.835462       0.719009
# Freedomtomakelifechoices -0.546606         0.566742  0.379079       0.447333
# Generosity               -0.047993         0.075824 -0.079662      -0.048126
# Perceptionsofcorruption  -0.351959         0.385613  0.298920       0.181899
# ...

# %% [markdown]
# #### Burada anlaşıldığı gibi ekonomi ve yaşam kalitesi iyi ise mutluluk sıralamasında en üste olabilirsin.

# %%
turkiye_2015=df[df["ülke"]=="Turkey"]
turkiye_2016=df2016[df2016["Country"]=="Turkey"]
turkiye_2017=df2017[df2017["Country"]=="Turkey"]
turkiye_2018=df2018[df2018["Country"]=="Turkey"]
turkiye_2019=df2019[df2019["Country"]=="Turkey"]

# %%
turkiye_2015.head(1)
# Out:
#       ülke                            Bolge  Happiness_Rank  Mutluluk_Skor  \
# 75  Turkey  Middle East and Northern Africa              76          5.332
#
#     Standard_Error  Economy_(GDP_per_Capita)   Family  Yasam_Kalitesi  \
# 75         0.03864                   1.06098  0.94632         0.73172
#
#     Ozgurluk  Trust_(Government_Corruption)  Generosity  Dystopia_Residual
# 75   0.22815                        0.15746     0.12253            2.08528

# %%
turkiye_2016.head(1)
# Out:
#    Country                           Region  Rank  Happiness_Score  \
# 77  Turkey  Middle East and Northern Africa    78            5.389
#
#     Lower_Confidence_Interval  Upper_Confidence_Interval  Economy   Family  \
# 77                      5.295                      5.483  1.16492  0.87717
#
#     Life_Expectancy  Freedom  Government_Corruption  Generosity  \
# 77          0.64718  0.23889                0.12348     0.04707
#
#     Dystopia_Residual
# 77            2.29074

# %%
turkiye_2017.head(1)
# Out:
#    Country  Rank  Happiness_Score  Whisker_high  Whisker_low   Economy  \
# 68  Turkey    69              5.5      5.594865     5.405135  1.198274
#
#       Family  Life_Expectancy   Freedom  Generosity  Government_Corruption  \
# 68  1.337753         0.637606  0.300741    0.046693               0.099672
#
#     Dystopia_Residual
# 68           1.879278

# %%
turkiye_2018.head(1)
# Out:
#    Country                           Region  Rank  Happiness_Score  \
# 77  Turkey  Middle East and Northern Africa    78            5.389
#
#     Lower_Confidence_Interval  Upper_Confidence_Interval  Economy   Family  \
# 77                      5.295                      5.483  1.16492  0.87717
#
#     Life_Expectancy  Freedom  Government_Corruption  Generosity  \
# 77          0.64718  0.23889                0.12348     0.04707
#
#     Dystopia_Residual
# 77            2.29074

# %%
turkiye_2019.head(1)
# Out:
#     Rank Country  Happiness_Score  Economy  Socialsupport  Life_Expectancy  \
# 78    79  Turkey            5.373    1.183           1.36            0.808
#
#     Freedomtomakelifechoices  Generosity  Perceptionsofcorruption
# 78                     0.195       0.083                    0.106

# %%
average_ranking_2015 = turkiye_2015["Economy_(GDP_per_Capita)"].mean()
average_ranking_2016 = turkiye_2016["Economy"].mean()
average_ranking_2017 = turkiye_2017["Economy"].mean()
average_ranking_2018 = turkiye_2018["Economy"].mean()
average_ranking_2019 = turkiye_2019["Economy"].mean()

# %%
years = ["2015","2016", "2017", "2018","2019"]
average_rankingsT = [average_ranking_2015,average_ranking_2016, average_ranking_2017, average_ranking_2018,average_ranking_2019]

plt.plot(years, average_rankingsT, marker="o")
plt.xlabel("Yıllar")
plt.ylabel("Ortalama Ekonomi")
plt.title("Türkiyenin Yıllara Göre Ortlama Ekonomisi")
plt.show()

# %%
sns.barplot( y=average_rankingsT,x =years)
plt.title("Türkiye'nin yıllara göre prtlama ekonomisi", size=15)
plt.xlabel("Yıllar")
plt.ylabel("Ortlama ekonomisi")
# Out:
# Text(0, 0.5, 'Ortlama ekonomisi')

# %%
almanya_2015=df[df["ülke"]=="Germany"]
almanya_2016=df2016[df2016["Country"]=="Germany"]
almanya_2017=df2017[df2017["Country"]=="Germany"]
almanya_2018=df2018[df2018["Country"]=="Germany"]
almanya_2019=df2019[df2019["Country"]=="Germany"]

# %%
almanya_2015.head(1)
# Out:
#        ülke           Bolge  Happiness_Rank  Mutluluk_Skor  Standard_Error  \
# 25  Germany  Western Europe              26           6.75         0.01848
#
#     Economy_(GDP_per_Capita)   Family  Yasam_Kalitesi  Ozgurluk  \
# 25                   1.32792  1.29937         0.89186   0.61477
#
#     Trust_(Government_Corruption)  Generosity  Dystopia_Residual
# 25                        0.21843     0.28214            2.11569

# %%
average_ranking_G2015 = almanya_2015["Mutluluk_Skor"].mean()
average_ranking_G2016 = almanya_2016["Happiness_Score"].mean()
average_ranking_G2017 = almanya_2017["Happiness_Score"].mean()
average_ranking_G2018 = almanya_2018["Happiness_Score"].mean()
average_ranking_G2019 = almanya_2019["Happiness_Score"].mean()

# %%
years = ["2015","2016", "2017", "2018","2019"]
average_rankingsG = [average_ranking_G2015,average_ranking_G2016, average_ranking_G2017, average_ranking_G2018,average_ranking_G2019]

# %%
plt.plot(years, average_rankingsG, marker="o")
plt.xlabel("Yıllar")
plt.ylabel("Mutluluk Skoru")
plt.title("Almanya Yıllara Göre Ortlama Mutluluk Skoru")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(years, average_rankingsG)
ax.set_xlabel('Yıllar')
ax.set_ylabel('Mutluluk Puanı')
plt.show()

# %%
sns.barplot(x=years,y=average_rankingsG)
plt.title("Almanya'nın yıllara göre ortalama mutluluk skoru", size=15)
plt.xlabel("Yıllar")
plt.ylabel("ortalama mutluluk skoru")
# Out:
# Text(0, 0.5, 'ortalama mutluluk skoru')

# %%
farkAlmanya=average_ranking_G2019-average_ranking_G2015.round(3)

# %%
print(farkAlmanya)
# Out:
# 0.23500000000000032

# %%
farkTurkey=average_ranking_2019-average_ranking_2015
farkTurkey
# Out:
# 0.12202000000000002
